# %% [markdown]
# <a href="https://colab.research.google.com/github/zaiunibo-ops/C/blob/main/tryna.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('hello world')
# Out:
# hello world

# %%
print('kets see what are we doing')
# Out:
# kets see what are we doing
